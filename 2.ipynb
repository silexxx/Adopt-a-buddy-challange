# %%
import numpy as np
import pandas as pd

# %%
test = pd.read_csv("test.csv")
train = pd.read_csv("train.csv")

# %%
filename='xgc7.csv'
submission=pd.read_csv(filename)
submission.head()
# Out:
#        pet_id  breed_category  pet_category
# 0  ANSL_75005               1             2
# 1  ANSL_76663               0             1
# 2  ANSL_58259               0             2
# 3  ANSL_67171               0             2
# 4  ANSL_72871               0             2

# %%
test
# Out:
#           pet_id           issue_date         listing_date  condition  \
# 0     ANSL_75005  2005-08-17 00:00:00  2017-09-07 15:35:00        0.0
# 1     ANSL_76663  2018-11-15 00:00:00  2019-05-08 17:24:00        1.0
# 2     ANSL_58259  2012-10-11 00:00:00  2018-04-02 16:51:00        1.0
# 3     ANSL_67171  2015-02-13 00:00:00  2018-04-06 07:25:00        1.0
# 4     ANSL_72871  2017-01-18 00:00:00  2018-04-26 13:42:00        1.0
# ...          ...                  ...                  ...        ...
# 8067  ANSL_66809  2016-02-10 00:00:00  2017-03-10 14:56:00        2.0
# 8068  ANSL_59041  2015-12-07 00:00:00  2018-02-12 00:00:00        0.0
# 8069  ANSL_60034  2015-12-08 00:00:00  2017-01-04 17:19:00        0.0
# 8070  ANSL_58066  2016-06-28 00:00:00  2017-07-20 18:19:00        NaN
# 8071  ANSL_69436  2016-02-02 00:00:00  2017-02-28 16:47:00        0.0
#
#         color_type  length(m)  height(cm)  X1  X2
# 0            Black       0.87       42.73   0   7
# 1     Orange Tabby       0.06        6.71   0   1
# 2            Black       0.24       41.21   0   7
# 3            Black       0.29        8.46   7   1
# 4            Brown       0.71       30.92   0   7
# ...            ...        ...         ...  ..  ..
# 8067         Brown       0.82       36.08  13   9
# 8068           Tan       0.49       27.54  13   9
# 8069         Black       0.98       37.19   0   7
# 8070         Black       0.79       23.83   0   2
# 8071         Black       0.64       24.51   0   1
#
# [8072 rows x 9 columns]

# %%
test["breed_category"]=submission["breed_category"].copy()

# %%
test
# Out:
#           pet_id           issue_date         listing_date  condition  \
# 0     ANSL_75005  2005-08-17 00:00:00  2017-09-07 15:35:00        0.0
# 1     ANSL_76663  2018-11-15 00:00:00  2019-05-08 17:24:00        1.0
# 2     ANSL_58259  2012-10-11 00:00:00  2018-04-02 16:51:00        1.0
# 3     ANSL_67171  2015-02-13 00:00:00  2018-04-06 07:25:00        1.0
# 4     ANSL_72871  2017-01-18 00:00:00  2018-04-26 13:42:00        1.0
# ...          ...                  ...                  ...        ...
# 8067  ANSL_66809  2016-02-10 00:00:00  2017-03-10 14:56:00        2.0
# 8068  ANSL_59041  2015-12-07 00:00:00  2018-02-12 00:00:00        0.0
# 8069  ANSL_60034  2015-12-08 00:00:00  2017-01-04 17:19:00        0.0
# 8070  ANSL_58066  2016-06-28 00:00:00  2017-07-20 18:19:00        NaN
# 8071  ANSL_69436  2016-02-02 00:00:00  2017-02-28 16:47:00        0.0
#
#         color_type  length(m)  height(cm)  X1  X2  breed_category
# 0            Black       0.87       42.73   0   7               1
# 1     Orange Tabby       0.06        6.71   0   1               0
# 2            Black       0.24       41.21   0   7               0
# 3            Black       0.29        8.46   7   1               0
# 4            Brown       0.71       30.92   0   7               0
# ...            ...        ...         ...  ..  ..             ...
# 8067         Brown       0.82       36.08  13   9               0
# 8068           Tan       0.49       27.54  13   9               1
# 8069         Black       0.98       37.19   0   7               1
# 8070         Black       0.79       23.83   0   2               2
# 8071         Black       0.64       24.51   0   1               1
#
# [8072 rows x 10 columns]

# %%
train
# Out:
#            pet_id           issue_date         listing_date  condition  \
# 0      ANSL_69903  2016-07-10 00:00:00  2016-09-21 16:25:00        2.0
# 1      ANSL_66892  2013-11-21 00:00:00  2018-12-27 17:47:00        1.0
# 2      ANSL_69750  2014-09-28 00:00:00  2016-10-19 08:24:00        NaN
# 3      ANSL_71623  2016-12-31 00:00:00  2019-01-25 18:30:00        1.0
# 4      ANSL_57969  2017-09-28 00:00:00  2017-11-19 09:38:00        2.0
# ...           ...                  ...                  ...        ...
# 18829  ANSL_51738  2017-01-26 00:00:00  2018-03-09 15:35:00        2.0
# 18830  ANSL_59900  2016-06-18 00:00:00  2017-07-09 08:37:00        NaN
# 18831  ANSL_53210  2010-07-21 00:00:00  2018-08-22 14:27:00        0.0
# 18832  ANSL_63468  2017-05-12 00:00:00  2018-02-08 14:05:00        0.0
# 18833  ANSL_73558  2011-12-13 00:00:00  2018-10-26 14:18:00        0.0
#
#          color_type  length(m)  height(cm)  X1  X2  breed_category  \
# 0       Brown Tabby       0.80        7.78  13   9             0.0
# 1             White       0.72       14.19  13   9             0.0
# 2             Brown       0.15       40.90  15   4             2.0
# 3             White       0.62       17.82   0   1             0.0
# 4             Black       0.50       11.06  18   4             0.0
# ...             ...        ...         ...  ..  ..             ...
# 18829      Tricolor       0.44       27.36   0   1             0.0
# 18830         Brown       0.73       14.25  15   4             2.0
# 18831  Calico Point       0.99       28.13  13   9             1.0
# 18832           Tan       0.55       44.82  13   9             1.0
# 18833         Brown       0.86       37.40   0   1             1.0
#
#        pet_category
# 0                 1
# 1                 2
# 2                 4
# 3                 2
# 4                 1
# ...             ...
# 18829             2
# 18830             4
# 18831             1
# 18832             2
# 18833             2
#
# [18834 rows x 11 columns]

# %%
test
# Out:
#           pet_id           issue_date         listing_date  condition  \
# 0     ANSL_75005  2005-08-17 00:00:00  2017-09-07 15:35:00        0.0
# 1     ANSL_76663  2018-11-15 00:00:00  2019-05-08 17:24:00        1.0
# 2     ANSL_58259  2012-10-11 00:00:00  2018-04-02 16:51:00        1.0
# 3     ANSL_67171  2015-02-13 00:00:00  2018-04-06 07:25:00        1.0
# 4     ANSL_72871  2017-01-18 00:00:00  2018-04-26 13:42:00        1.0
# ...          ...                  ...                  ...        ...
# 8067  ANSL_66809  2016-02-10 00:00:00  2017-03-10 14:56:00        2.0
# 8068  ANSL_59041  2015-12-07 00:00:00  2018-02-12 00:00:00        0.0
# 8069  ANSL_60034  2015-12-08 00:00:00  2017-01-04 17:19:00        0.0
# 8070  ANSL_58066  2016-06-28 00:00:00  2017-07-20 18:19:00        NaN
# 8071  ANSL_69436  2016-02-02 00:00:00  2017-02-28 16:47:00        0.0
#
#         color_type  length(m)  height(cm)  X1  X2  breed_category
# 0            Black       0.87       42.73   0   7               1
# 1     Orange Tabby       0.06        6.71   0   1               0
# 2            Black       0.24       41.21   0   7               0
# 3            Black       0.29        8.46   7   1               0
# 4            Brown       0.71       30.92   0   7               0
# ...            ...        ...         ...  ..  ..             ...
# 8067         Brown       0.82       36.08  13   9               0
# 8068           Tan       0.49       27.54  13   9               1
# 8069         Black       0.98       37.19   0   7               1
# 8070         Black       0.79       23.83   0   2               2
# 8071         Black       0.64       24.51   0   1               1
#
# [8072 rows x 10 columns]

# %%
train.drop(['pet_category'],axis=1)
# Out:
#            pet_id           issue_date         listing_date  condition  \
# 0      ANSL_69903  2016-07-10 00:00:00  2016-09-21 16:25:00        2.0
# 1      ANSL_66892  2013-11-21 00:00:00  2018-12-27 17:47:00        1.0
# 2      ANSL_69750  2014-09-28 00:00:00  2016-10-19 08:24:00        NaN
# 3      ANSL_71623  2016-12-31 00:00:00  2019-01-25 18:30:00        1.0
# 4      ANSL_57969  2017-09-28 00:00:00  2017-11-19 09:38:00        2.0
# ...           ...                  ...                  ...        ...
# 18829  ANSL_51738  2017-01-26 00:00:00  2018-03-09 15:35:00        2.0
# 18830  ANSL_59900  2016-06-18 00:00:00  2017-07-09 08:37:00        NaN
# 18831  ANSL_53210  2010-07-21 00:00:00  2018-08-22 14:27:00        0.0
# 18832  ANSL_63468  2017-05-12 00:00:00  2018-02-08 14:05:00        0.0
# 18833  ANSL_73558  2011-12-13 00:00:00  2018-10-26 14:18:00        0.0
#
#          color_type  length(m)  height(cm)  X1  X2  breed_category
# 0       Brown Tabby       0.80        7.78  13   9             0.0
# 1             White       0.72       14.19  13   9             0.0
# 2             Brown       0.15       40.90  15   4             2.0
# 3             White       0.62       17.82   0   1             0.0
# 4             Black       0.50       11.06  18   4             0.0
# ...             ...        ...         ...  ..  ..             ...
# 18829      Tricolor       0.44       27.36   0   1             0.0
# 18830         Brown       0.73       14.25  15   4             2.0
# 18831  Calico Point       0.99       28.13  13   9             1.0
# 18832           Tan       0.55       44.82  13   9             1.0
# 18833         Brown       0.86       37.40   0   1             1.0
#
# [18834 rows x 10 columns]

# %%
dataset = pd.concat([train.drop(['pet_category'],axis=1),test])
dataset['issue_date'] = pd.to_datetime(dataset['issue_date'])
dataset['listing_date'] = pd.to_datetime(dataset['listing_date'])
dataset['duration'] = (dataset['listing_date'] - dataset['issue_date']).dt.days  

dataset['1stnum'] = dataset['pet_id'].str[:6]
dataset['1st2num'] = dataset['pet_id'].str[:7]

dataset = dataset.drop(['pet_id'],axis=1)
dataset
# Out:
#      issue_date        listing_date  condition   color_type  length(m)  \
# 0    2016-07-10 2016-09-21 16:25:00        2.0  Brown Tabby       0.80
# 1    2013-11-21 2018-12-27 17:47:00        1.0        White       0.72
# 2    2014-09-28 2016-10-19 08:24:00        NaN        Brown       0.15
# 3    2016-12-31 2019-01-25 18:30:00        1.0        White       0.62
# 4    2017-09-28 2017-11-19 09:38:00        2.0        Black       0.50
# ...         ...                 ...        ...          ...        ...
# 8067 2016-02-10 2017-03-10 14:56:00        2.0        Brown       0.82
# 8068 2015-12-07 2018-02-12 00:00:00        0.0          Tan       0.49
# 8069 2015-12-08 2017-01-04 17:19:00        0.0        Black       0.98
# 8070 2016-06-28 2017-07-20 18:19:00        NaN        Black       0.79
# 8071 2016-02-02 2017-02-28 16:47:00        0.0        Black       0.64
#
#       height(cm)  X1  X2  breed_category  duration  1stnum  1st2num
# 0           7.78  13   9             0.0        73  ANSL_6  ANSL_69
# 1          14.19  13   9             0.0      1862  ANSL_6  ANSL_66
# 2          40.90  15   4             2.0       752  ANSL_6  ANSL_69
# 3          17.82   0   1             0.0       755  ANSL_7  ANSL_71
# 4          11.06  18   4             0.0        52  ANSL_5  ANSL_57
# ...          ...  ..  ..             ...       ...     ...      ...
# 8067       36.08  13   9             0.0       394  ANSL_6  ANSL_66
# 8068       27.54  13   9             1.0       798  ANSL_5  ANSL_59
# 8069       37.19   0   7             1.0       393  ANSL_6  ANSL_60
# 8070       23.83   0   2             2.0       387  ANSL_5  ANSL_58
# 8071       24.51   0   1             1.0       392  ANSL_6  ANSL_69
#
# [26906 rows x 12 columns]

# %%
x=[]
for d in dataset['issue_date']:
    y=d.month
    x.append(y)
dataset['issue_month']=x

# %%
x=[]
for d in dataset['listing_date']:
    y=d.month
    x.append(y)
dataset['listing_month']=x

# %%
x=[]
for d in dataset['listing_date']:
    y=d.year+(d.month/12.0)+(d.day/365.0)
    x.append(y)
dataset['modified_listing_date']=x

# %%
x=[]
for d in dataset['issue_date']:
    y=d.year+(d.month/12.0)+(d.day/365.0)
    x.append(y)
dataset['modified_issue_date']=x

# %%
dataset['took_time']=abs(dataset['modified_listing_date']-dataset['modified_issue_date'])

# %%
dataset["breed_category"].isnull().values.any()
# Out:
# False

# %%
dataset.head()
# Out:
#   issue_date        listing_date  condition   color_type  length(m)  \
# 0 2016-07-10 2016-09-21 16:25:00        2.0  Brown Tabby       0.80
# 1 2013-11-21 2018-12-27 17:47:00        1.0        White       0.72
# 2 2014-09-28 2016-10-19 08:24:00        NaN        Brown       0.15
# 3 2016-12-31 2019-01-25 18:30:00        1.0        White       0.62
# 4 2017-09-28 2017-11-19 09:38:00        2.0        Black       0.50
#
#    height(cm)  X1  X2  breed_category  duration  1stnum  1st2num  issue_month  \
# 0        7.78  13   9             0.0        73  ANSL_6  ANSL_69            7
# 1       14.19  13   9             0.0      1862  ANSL_6  ANSL_66           11
# 2       40.90  15   4             2.0       752  ANSL_6  ANSL_69            9
# 3       17.82   0   1             0.0       755  ANSL_7  ANSL_71           12
# 4       11.06  18   4             0.0        52  ANSL_5  ANSL_57            9
#
#    listing_month  modified_listing_date  modified_issue_date  took_time
# 0              9            2016.807534          2016.610731   0.196804
# 1             12            2019.073973          2013.974201   5.099772
# 2             10            2016.885388          2014.826712   2.058676
# 3              1            2019.151826          2017.084932   2.066895
# 4             11            2017.968721          2017.826712   0.142009

# %%
dataset['height(cm)'] = dataset['height(cm)'].apply(lambda x: x*0.01)

# %%
info = pd.DataFrame()
info['length(m)'] = [np.percentile(dataset['length(m)'],25*i) for i in range(1,4)]
info['height(cm)'] = [np.percentile(dataset['height(cm)'],25*i) for i in range(1,4)]
info['duration'] = [np.percentile(dataset['duration'],25*i) for i in range(1,4)]
info
# Out:
#    length(m)  height(cm)  duration
# 0       0.25      0.1621     120.0
# 1       0.50      0.2736     392.0
# 2       0.76      0.3878    1116.0

# %%
info.loc[3] = [2.5*info.loc[0,column] - 1.5*info.loc[2,column] for column in info.columns]
info.loc[4] = [2.5*info.loc[2,column] - 1.5*info.loc[0,column] for column in info.columns]
info
# Out:
#    length(m)  height(cm)  duration
# 0      0.250     0.16210     120.0
# 1      0.500     0.27360     392.0
# 2      0.760     0.38780    1116.0
# 3     -0.515    -0.17645   -1374.0
# 4      1.525     0.72635    2610.0

# %% [markdown]
# * Q1 - 1.5 * IQR or Q3 + 1.5 * IQR
# * Q1 - 1.5 * (Q3-Q1) or Q3 + 1.5 * (Q3-Q1)
# * 2.5 Q1 - 1.5 Q3 or 2.5 Q3 - 1.5 Q1

# %%
def range_part(column,value):
    if value > info.loc[4,column]:
        return 5
    elif value > info.loc[2,column]:
        return 4
    elif value > info.loc[1,column]:
        return 3
    elif value > info.loc[0,column]:
        return 2
    elif value > info.loc[3,column]:
        return 1
    else:
        return 0

# %%
dataset.dtypes
# Out:
# issue_date               datetime64[ns]
# listing_date             datetime64[ns]
# condition                       float64
# color_type                       object
# length(m)                       float64
# height(cm)                      float64
# X1                                int64
# X2                                int64
# breed_category                  float64
# duration                          int64
# 1stnum                           object
# 1st2num                          object
# issue_month                       int64
# listing_month                     int64
# modified_listing_date           float64
# modified_issue_date             float64
# took_time                       float64
# dtype: object

# %%
dataset.isnull().sum()
# Out:
# issue_date                  0
# listing_date                0
# condition                2096
# color_type                  0
# length(m)                   0
# height(cm)                  0
# X1                          0
# X2                          0
# breed_category              0
# duration                    0
# 1stnum                      0
# 1st2num                     0
# issue_month                 0
# listing_month               0
# modified_listing_date       0
# modified_issue_date         0
# took_time                   0
# dtype: int64

# %%
numerical = dataset.dtypes[dataset.dtypes != object].index

# %%
# from tqdm import tqdm
# tqdm.pandas()
# dataset['length_range'] = dataset['length(m)'].progress_apply(lambda x:range_part('length(m)',x))
# dataset['height_range'] = dataset['height(cm)'].progress_apply(lambda x:range_part('height(cm)',x))
# dataset['duration_range'] = dataset['duration'].progress_apply(lambda x:range_part('duration',x))
# dataset.head(5)

# %%
from tqdm import tqdm
tqdm.pandas()
dataset['length_range'] = dataset['length(m)']
dataset['height_range'] = dataset['height(cm)']
dataset['duration_range'] = dataset['duration']
dataset.head(5)
# Out:
# /home/daneshwar/anaconda3/lib/python3.7/site-packages/tqdm/std.py:658: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
#   issue_date        listing_date  condition   color_type  length(m)  \
# 0 2016-07-10 2016-09-21 16:25:00        2.0  Brown Tabby       0.80
# 1 2013-11-21 2018-12-27 17:47:00        1.0        White       0.72
# 2 2014-09-28 2016-10-19 08:24:00        NaN        Brown       0.15
# 3 2016-12-31 2019-01-25 18:30:00        1.0        White       0.62
# 4 2017-09-28 2017-11-19 09:38:00        2.0        Black       0.50
#
#    height(cm)  X1  X2  breed_category  duration  1stnum  1st2num  issue_month  \
# 0      0.0778  13   9             0.0        73  ANSL_6  ANSL_69            7
# 1      0.1419  13   9             0.0      1862  ANSL_6  ANSL_66           11
# 2      0.4090  15   4             2.0       752  ANSL_6  ANSL_69            9
# 3      0.1782   0   1             0.0       755  ANSL_7  ANSL_71           12
# 4      0.1106  18   4             0.0        52  ANSL_5  ANSL_57            9
#
#    listing_month  modified_listing_date  modified_issue_date  took_time  \
# 0              9            2016.807534          2016.610731   0.196804
# 1             12            2019.073973          2013.974201   5.099772
# 2             10            2016.885388          2014.826712   2.058676
# 3              1            2019.151826          2017.084932   2.066895
# 4             11            2017.968721          2017.826712   0.142009
#
#    length_range  height_range  duration_range
# 0          0.80        0.0778              73
# 1          0.72        0.1419            1862
# 2          0.15        0.4090             752
# 3          0.62        0.1782             755
# 4          0.50        0.1106              52

# %%
# import random
# dataset.fillna(method='ffill', inplace=True)
# dataset.head(5)

# %%
dataset.head(5)
# Out:
#   issue_date        listing_date  condition   color_type  length(m)  \
# 0 2016-07-10 2016-09-21 16:25:00        2.0  Brown Tabby       0.80
# 1 2013-11-21 2018-12-27 17:47:00        1.0        White       0.72
# 2 2014-09-28 2016-10-19 08:24:00        NaN        Brown       0.15
# 3 2016-12-31 2019-01-25 18:30:00        1.0        White       0.62
# 4 2017-09-28 2017-11-19 09:38:00        2.0        Black       0.50
#
#    height(cm)  X1  X2  breed_category  duration  1stnum  1st2num  issue_month  \
# 0      0.0778  13   9             0.0        73  ANSL_6  ANSL_69            7
# 1      0.1419  13   9             0.0      1862  ANSL_6  ANSL_66           11
# 2      0.4090  15   4             2.0       752  ANSL_6  ANSL_69            9
# 3      0.1782   0   1             0.0       755  ANSL_7  ANSL_71           12
# 4      0.1106  18   4             0.0        52  ANSL_5  ANSL_57            9
#
#    listing_month  modified_listing_date  modified_issue_date  took_time  \
# 0              9            2016.807534          2016.610731   0.196804
# 1             12            2019.073973          2013.974201   5.099772
# 2             10            2016.885388          2014.826712   2.058676
# 3              1            2019.151826          2017.084932   2.066895
# 4             11            2017.968721          2017.826712   0.142009
#
#    length_range  height_range  duration_range
# 0          0.80        0.0778              73
# 1          0.72        0.1419            1862
# 2          0.15        0.4090             752
# 3          0.62        0.1782             755
# 4          0.50        0.1106              52

# %%
from sklearn.preprocessing import LabelEncoder
dataset['color_number'] = LabelEncoder().fit_transform(dataset['color_type'])
dataset['issue_date'] = LabelEncoder().fit_transform(dataset['issue_date'])
dataset['listing_date'] = LabelEncoder().fit_transform(dataset['listing_date'])

dataset['1stnum'] = LabelEncoder().fit_transform(dataset['1stnum'])
dataset['1st2num'] = LabelEncoder().fit_transform(dataset['1st2num'])

dataset["condition"]=dataset["condition"].fillna(-1)
dataset = dataset[["took_time",'breed_category','issue_date','listing_date','condition','length_range','height_range','duration_range','color_number','X1','X2']]
dataset.head(5)
# Out:
#    took_time  breed_category  issue_date  listing_date  condition  \
# 0   0.196804             0.0        3387          1616        2.0
# 1   5.099772             0.0        2446         20535        1.0
# 2   2.058676             2.0        2744          2441       -1.0
# 3   2.066895             0.0        3560         21255        1.0
# 4   0.142009             0.0        3828         11476        2.0
#
#    length_range  height_range  duration_range  color_number  X1  X2
# 0          0.80        0.0778              73            18  13   9
# 1          0.72        0.1419            1862            53  13   9
# 2          0.15        0.4090             752            15  15   4
# 3          0.62        0.1782             755            53   0   1
# 4          0.50        0.1106              52             2  18   4

# %%
dataset.isnull().sum()
# Out:
# took_time         0
# breed_category    0
# issue_date        0
# listing_date      0
# condition         0
# length_range      0
# height_range      0
# duration_range    0
# color_number      0
# X1                0
# X2                0
# dtype: int64

# %%
dataset.drop(columns=["height_range","breed_category"],inplace=True)
dataset.head(5)
# Out:
# /home/daneshwar/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#    took_time  issue_date  listing_date  condition  length_range  \
# 0   0.196804        3387          1616        2.0          0.80
# 1   5.099772        2446         20535        1.0          0.72
# 2   2.058676        2744          2441       -1.0          0.15
# 3   2.066895        3560         21255        1.0          0.62
# 4   0.142009        3828         11476        2.0          0.50
#
#    duration_range  color_number  X1  X2
# 0              73            18  13   9
# 1            1862            53  13   9
# 2             752            15  15   4
# 3             755            53   0   1
# 4              52             2  18   4

# %%
dataset.iloc[:len(train)]
# Out:
#        took_time  issue_date  listing_date  condition  length_range  \
# 0       0.196804        3387          1616        2.0          0.80
# 1       5.099772        2446         20535        1.0          0.72
# 2       2.058676        2744          2441       -1.0          0.15
# 3       2.066895        3560         21255        1.0          0.62
# 4       0.142009        3828         11476        2.0          0.50
# ...          ...         ...           ...        ...           ...
# 18829   1.120091        3586         13960        2.0          0.44
# 18830   1.058676        3365          8376       -1.0          0.73
# 18831   8.086073        1410         17327        0.0          0.99
# 18832   0.739041        3691         13298        0.0          0.55
# 18833   6.868950        1819         19000        0.0          0.86
#
#        duration_range  color_number  X1  X2
# 0                  73            18  13   9
# 1                1862            53  13   9
# 2                 752            15  15   4
# 3                 755            53   0   1
# 4                  52             2  18   4
# ...               ...           ...  ..  ..
# 18829             407            52   0   1
# 18830             386            15  15   4
# 18831            2954            22  13   9
# 18832             272            48  13   9
# 18833            2509            15   0   1
#
# [18834 rows x 9 columns]

# %%
test
# Out:
#           pet_id           issue_date         listing_date  condition  \
# 0     ANSL_75005  2005-08-17 00:00:00  2017-09-07 15:35:00        0.0
# 1     ANSL_76663  2018-11-15 00:00:00  2019-05-08 17:24:00        1.0
# 2     ANSL_58259  2012-10-11 00:00:00  2018-04-02 16:51:00        1.0
# 3     ANSL_67171  2015-02-13 00:00:00  2018-04-06 07:25:00        1.0
# 4     ANSL_72871  2017-01-18 00:00:00  2018-04-26 13:42:00        1.0
# ...          ...                  ...                  ...        ...
# 8067  ANSL_66809  2016-02-10 00:00:00  2017-03-10 14:56:00        2.0
# 8068  ANSL_59041  2015-12-07 00:00:00  2018-02-12 00:00:00        0.0
# 8069  ANSL_60034  2015-12-08 00:00:00  2017-01-04 17:19:00        0.0
# 8070  ANSL_58066  2016-06-28 00:00:00  2017-07-20 18:19:00        NaN
# 8071  ANSL_69436  2016-02-02 00:00:00  2017-02-28 16:47:00        0.0
#
#         color_type  length(m)  height(cm)  X1  X2  breed_category
# 0            Black       0.87       42.73   0   7               1
# 1     Orange Tabby       0.06        6.71   0   1               0
# 2            Black       0.24       41.21   0   7               0
# 3            Black       0.29        8.46   7   1               0
# 4            Brown       0.71       30.92   0   7               0
# ...            ...        ...         ...  ..  ..             ...
# 8067         Brown       0.82       36.08  13   9               0
# 8068           Tan       0.49       27.54  13   9               1
# 8069         Black       0.98       37.19   0   7               1
# 8070         Black       0.79       23.83   0   2               2
# 8071         Black       0.64       24.51   0   1               1
#
# [8072 rows x 10 columns]

# %%
X_tr, z_tr = dataset.iloc[:len(train)], train['pet_category']
X_test = dataset.iloc[len(train):]

# %%
import pandas as pd
import numpy as np
X = dataset.iloc[:len(train)] 
y = train['pet_category']  
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(X,y)
print(model.feature_importances_) 

feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# [0.1363343  0.10487273 0.08777977 0.08453605 0.07240191 0.13016712
#  0.19305424 0.12652077 0.06433311]

# %%
z_tr = train['pet_category']
from sklearn.model_selection import train_test_split
X_train_full, X_valid_full, y_train, y_valid = train_test_split(X_tr, z_tr, train_size=0.96, test_size=0.04,
                                                                random_state=0)


X_train = X_train_full.copy()
X_valid = X_valid_full.copy()
X_test = X_test.copy()


from xgboost import XGBClassifier
model = XGBClassifier(learning_rate=0.4,  
                      colsample_bytree = 0.9,
                      subsample = 0.8,
                      objective='binary:hinge', 
                      n_estimators=500, 
                      reg_alpha = 0.3,
                      max_depth=9, 
                      gamma=1,
                     reg_lambda=4)


from sklearn.metrics import mean_absolute_error

model.fit(X_train, y_train, 
             early_stopping_rounds=250, 
             eval_set=[(X_valid, y_valid)], 
             verbose=False) 


predictions =  model.predict(X_valid)
z_RF = model.predict(X_test)


mae_3 = mean_absolute_error(predictions, y_valid)
print("Mean Absolute Error:" , mae_3)
# Out:
# Mean Absolute Error: 0.11671087533156499

# %% [markdown]
# 0.11671087533156499

# %% [markdown]
# 0.09447983014861996

# %% [markdown]
# 0.10193788160339792

# %%
# import eli5
# from eli5.sklearn import PermutationImportance

# perm = PermutationImportance(model, random_state=1).fit(X_valid, y_valid)
# eli5.show_weights(perm, feature_names = X_valid.columns.tolist())

# %%
from matplotlib import pyplot
pyplot.bar(dataset.columns, model.feature_importances_)
pyplot.xticks(dataset.columns, rotation='vertical')
pyplot.show()

# %%
X_test
# Out:
#       took_time  issue_date  listing_date  condition  length_range  \
# 0     12.055936         378          9687        0.0          0.87
# 1      0.480822        4237         23768        1.0          0.06
# 2      5.475342        2077         14511        1.0          0.24
# 3      3.147489        2882         14573        1.0          0.29
# 4      1.271918        3578         14982        1.0          0.71
# ...         ...         ...           ...        ...           ...
# 8067   1.083333        3239          5945        2.0          0.82
# 8068   2.180365        3174         13368        0.0          0.49
# 8069   1.072374        3175          4475        0.0          0.98
# 8070   1.061416        3375          8630       -1.0          0.79
# 8071   1.071233        3231          5714        0.0          0.64
#
#       duration_range  color_number  X1  X2
# 0               4404             2   0   7
# 1                174            38   0   1
# 2               1999             2   0   7
# 3               1148             2   7   1
# 4                463            15   0   7
# ...              ...           ...  ..  ..
# 8067             394            15  13   9
# 8068             798            48  13   9
# 8069             393             2   0   7
# 8070             387             2   0   2
# 8071             392             2   0   1
#
# [8072 rows x 9 columns]

# %%
z_RF=z_RF.astype("int64")
z_RF.dtype
# Out:
# dtype('int64')

# %%
test
# Out:
#           pet_id           issue_date         listing_date  condition  \
# 0     ANSL_75005  2005-08-17 00:00:00  2017-09-07 15:35:00        0.0
# 1     ANSL_76663  2018-11-15 00:00:00  2019-05-08 17:24:00        1.0
# 2     ANSL_58259  2012-10-11 00:00:00  2018-04-02 16:51:00        1.0
# 3     ANSL_67171  2015-02-13 00:00:00  2018-04-06 07:25:00        1.0
# 4     ANSL_72871  2017-01-18 00:00:00  2018-04-26 13:42:00        1.0
# ...          ...                  ...                  ...        ...
# 8067  ANSL_66809  2016-02-10 00:00:00  2017-03-10 14:56:00        2.0
# 8068  ANSL_59041  2015-12-07 00:00:00  2018-02-12 00:00:00        0.0
# 8069  ANSL_60034  2015-12-08 00:00:00  2017-01-04 17:19:00        0.0
# 8070  ANSL_58066  2016-06-28 00:00:00  2017-07-20 18:19:00        NaN
# 8071  ANSL_69436  2016-02-02 00:00:00  2017-02-28 16:47:00        0.0
#
#         color_type  length(m)  height(cm)  X1  X2  breed_category
# 0            Black       0.87       42.73   0   7               1
# 1     Orange Tabby       0.06        6.71   0   1               0
# 2            Black       0.24       41.21   0   7               0
# 3            Black       0.29        8.46   7   1               0
# 4            Brown       0.71       30.92   0   7               0
# ...            ...        ...         ...  ..  ..             ...
# 8067         Brown       0.82       36.08  13   9               0
# 8068           Tan       0.49       27.54  13   9               1
# 8069         Black       0.98       37.19   0   7               1
# 8070         Black       0.79       23.83   0   2               2
# 8071         Black       0.64       24.51   0   1               1
#
# [8072 rows x 10 columns]

# %%
filename='xgc7.csv'
submission=pd.read_csv(filename)
submission['pet_category'] = z_RF
submission.to_csv(filename,index=False)

# %%
new=pd.read_csv('xgc7.csv')
new.head()
# Out:
#        pet_id  breed_category  pet_category
# 0  ANSL_75005               1             2
# 1  ANSL_76663               0             1
# 2  ANSL_58259               0             2
# 3  ANSL_67171               0             2
# 4  ANSL_72871               0             2
